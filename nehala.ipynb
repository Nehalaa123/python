# %%
n=int(input("Enter a number :"))
if n%7==0:
    print("divisible by 7")
else:
    print("not divisible by 7")
# Out:
# Enter a number :49
# divisible by 7

# %%
ch = input("Enter a character: ")
if ch in "a,e,i,o,u,A,E,I,O,U":
    print("ch is a vowel")
else:
    print("ch is not a vowel")
# Out:
# Enter a character: m
# ch is not a vowel

# %%
age=int(input("Enter the age:"))
if age>=18:
    print("Eligible to apply")
else:
    print("Not eligible to apply")
# Out:
# Enter the age:18
# Eligible to apply

# %%
str1=input("Enter first string:")
str2=input("enter second string:")
if str1==str2:
    print("both strings are equal")
else:
    print("both string are not equal")
# Out:
# Enter first string:hi
# enter second string:hello
# both string are not equal

# %%
amnt=float(input("Enter the amount:"))
if amnt>5000:
    print("Customer is eligible for discount")
else:
    print("Customer is not eligible")
# Out:
# Enter the amount:4500
# Customer is not eligible

# %%
n=int(input("Enter the number:"))
if n>=10 and n<=100:
    print("The number lies b/w 10 and 100")
else:
    print("The number does not lie b/w 10 and 100")
# Out:
# Enter the number:60
# The number lies b/w 10 and 100

# %%
attendance=float(input("Enter attendance percentage:"))
if attendance>=75:
    print("Student eligible to attend the exam")
else:
    print("Student is not eligible to attend the exam")
# Out:
# Enter attendance percentage:88
# Student eligible to attend the exam

# %%
ch=input("Enter an alphabet:")
if ch.isupper():
    print("The letter is uppercase")
else:
    print("The letter is lowercase")
# Out:
# Enter an alphabet:D
# The letter is uppercase

# %%
n=int(input("Enter the number:"))
if n>=100 and n<=999:
    print("The number is three-digits")
else:
    print("The number not a three-digits")
# Out:
# Enter the number:678
# The number is three-digits

# %%
data=float(input("Enter the mobile data used in GB:"))
if data<2:
    print("Low usage")
elif data<=5:
    print("Moderate usage")
else:
    print("High usage")
# Out:
# Enter the mobile data used in GB:7
# High usage
