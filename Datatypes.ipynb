# %%
marks=[85,70,30,67,27]
print("First Mark:",marks[0])
# Out:
# First Mark: 85

# %%
numbers=[10,20,30,40]
numbers.append(50)
print(numbers)
# Out:
# [10, 20, 30, 40, 50]

# %%
numbers=(30,20,10,60,70)
print("Third element:",numbers[2])
# Out:
# Third element: 10

# %%
numbers={10,20,20,50,10,60}
print(numbers)
# Out:
# {10, 20, 50, 60}

# %%
student={
    "name":"Fathima",
    "age":22,
    "mark":85
}
print("Name:",student["name"])
# Out:
# Name: Fathima

# %%
text="python"
print("First character:",text[0])
print("Last character:",text[-1])
# Out:
# First character: p
# Last character: n
